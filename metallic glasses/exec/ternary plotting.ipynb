# %%
# pip install python-ternary
# %matplotlib inline

import csv
import ternary
from bisect import bisect_left
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
data = []

with open('NiZrAl_all.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)

# %%
data = []

with open('NiZrAl_all.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []

for d in data:
    d[0] = float(d[0])
    d[1] = float(d[1])
    d[2] = float(d[2])
    d[3] = float(d[3])
    if d[3] == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
        ac.append(d[0:3])
    else:
        am.append(d[0:3])
        
data[0]
# Out:
# [90.0, 10.0, 0.0, 0.0]

# %%
len(am)
am[1]
amtuple = []
for row in am:
    amtuple.append((row[0],row[1],row[2]))
amtuple[0]
# Out:
# (60.0, 30.0, 10.0)

# %%
scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(8,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Ni", fontsize=fontsize)
tax.bottom_axis_label("Al", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")

tax.legend()
# tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/NiAlZr_exp.png",transparent=True)

# %%
data = []

with open('CoVZr_hitp.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []

for d in data:
    x = float(d[0]) # Co
    y = float(d[1]) # V
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    # order: bottom, right, left
    # order: V, Co, Zr
    
    if d[3] == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
        ac.append(d[0:3])
    else:
        am.append(d[0:3])
    
len(ac)
# Out:
# 0

# %%
data = []

with open('CoVZr_hitp.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []

# data = data[0::4]

for d in data:
    x = float(d[0]) # Co
    y = float(d[1]) # V
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    if d[3] == 0:
#     if d[3] == 0 and d[0]%2 == 0 and d[2]%2 == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
#     elif d[3] == 0.5 and d[0]%2 == 0 and d[2]%2 == 0:
        ac.append(d[0:3])
    else:
#     elif d[0]%2 == 0 and d[2]%2 == 0:
        am.append(d[0:3])
    
    # order: bottom, right, left
    # order: V, Co, Zr
# ac = ac[0::4]
# am = am[0::4]
# cr = cr[0::4]
print(len(ac)+len(am)+len(cr))
        
scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(8,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Co", fontsize=fontsize)
tax.bottom_axis_label("V", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
# tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")

tax.legend()
# tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/CoVZr_hitp.png",transparent=True)
# Out:
# 1323

# %%
data = []

with open('FeNbTi_hitp_1in4.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []
# data = data[0::4]

for d in data:
    x = float(d[0]) # Fe
    y = float(d[1]) # Nb
    z = float(d[2]) # Ti
    d[3] = float(d[3])
    
    d[0] = z
    d[1] = x
    d[2] = y
    
    # order: bottom, right, left
    # order: Ti, Fe, Nb
    
    if d[3] == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
        ac.append(d[0:3])
    else:
        am.append(d[0:3])
    
    
        
scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(8,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Nb", fontsize=fontsize)
tax.right_axis_label("Fe", fontsize=fontsize)
tax.bottom_axis_label("Ti", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
# tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")

tax.legend()
# tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/FeNbTi_hitp_1in4.png",transparent=True)

# %%
data = []

with open('CoFeZr_hitp_1in4.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []
# data = data[0::4]

for d in data:
    x = float(d[0]) # Co
    y = float(d[1]) # Fe
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
    if d[3] == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
        ac.append(d[0:3])
    else:
        am.append(d[0:3])
    
    
        
scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(8,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Co", fontsize=fontsize)
tax.bottom_axis_label("Fe", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
# tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")

tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/CoFeZr_hitp_1in4_labels.png",transparent=True)

# %%
data = []

with open('CoVZr_hitp_1in4_exp.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []
# data = data[0::4]

for d in data:
    x = float(d[0]) # Co
    y = float(d[1]) # V
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
    if d[3] == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
        ac.append(d[0:3])
    else:
        am.append(d[0:3])
    
    
        
scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(8,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Co", fontsize=fontsize)
tax.bottom_axis_label("V", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
# tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")

tax.legend()
# tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/CoVZr_hitp_1in4_exp.png",transparent=True)

# %%
data = []

with open('FeNbTi_experimental.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
data = data[1:]

am = []
ac = []
cr = []
# data = data[0::4]

for d in data:
    x = float(d[0]) # Fe
    y = float(d[1]) # Nb
    z = float(d[2]) # Ti
    d[3] = float(d[3])
    
    d[0] = z
    d[1] = x
    d[2] = y
    
    # order: bottom, right, left
    # order: Ti, Fe, Nb
    
    if d[3] == 0:
        cr.append(d[0:3])
    elif d[3] == 0.5:
        ac.append(d[0:3])
    else:
        am.append(d[0:3])
    
    
        
scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(8,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Nb", fontsize=fontsize)
tax.right_axis_label("Fe", fontsize=fontsize)
tax.bottom_axis_label("Ti", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

# tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
# tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")

tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/FeNbTi_exp.png",transparent=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-dcac31c7e187> in <module>()
#      49 # tax.scatter(am,marker='o', edgecolor='white', linewidth='1', facecolor='#440254',label = "AM")
#      50 # tax.scatter(ac,marker='s',edgecolor='black', linewidth='1',facecolor='green',label="AC")
# ---> 51 tax.scatter(cr,marker='o', edgecolor='black', linewidth='1', facecolor='yellow',label = "CR")
#      52
#      53 tax.legend()
#
# /anaconda/lib/python3.6/site-packages/ternary/ternary_axes_subplot.py in scatter(self, points, **kwargs)
#     357         permutation = self._permutation
#     358         plot_ = plotting.scatter(points, ax=ax, permutation=permutation,
# --> 359                                  **kwargs)
#     360         return plot_
#     361
#
# /anaconda/lib/python3.6/site-packages/ternary/plotting.py in scatter(points, ax, permutation, colorbar, colormap, vmin, vmax, scientific, cbarlabel, cb_kwargs, **kwargs)
#     145     if not ax:
#     146         fig, ax = pyplot.subplots()
# --> 147     xs, ys = project_sequence(points, permutation=permutation)
#     148     ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
#     149
#
# /anaconda/lib/python3.6/site-packages/ternary/helpers.py in project_sequence(s, permutation)
#     117     """
#     118
# --> 119     xs, ys = unzip([project_point(p, permutation=permutation) for p in s])
#     120     return xs, ys
#     121
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
data2 = []

with open('BMG_NiZrAl_predictions_test.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-147-81e6becc1f1f> in <module>()
#       1 data2 = []
#       2
# ----> 3 with open('BMG_NiZrAl_predictions_test.csv','r') as f:
#       4     reader = csv.reader(f)
#       5     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'BMG_NiZrAl_predictions_test.csv'

# %%
data2[1]
# Out:
# ['1.0', ' 0.0', ' 0.0', ' 0.123046875']

# %%
data2 = data2[1:]

for d in data2:
    d[0] = float(d[0])
    d[1] = float(d[1])
    d[2] = float(d[2])
    d[3] = float(d[3])
    
data2[1]
# Out:
# [15.0, 30.0, 55.0, 0.966796875]

# %%
d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]

# %%
def findClosest(myNumber,myList):
    """
    Assumes myList is sorted. Returns closest value to myNumber.

    If two numbers are equally close, return the smallest number.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return float(myList[0])
    if pos == len(myList):
        return float(myList[-1])
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
       return float(after)
    else:
       return float(before)

options = range(0,101,1)

def generate_heatmap_values(indices):
    # indices = [i,j,k]
    
    # find closest value for each given the scaling I'm currently using
#     i = findClosest(indices[0]*100,options)
#     j = findClosest(indices[1]*100,options)
    
    # if scale by 1, can just do:
    i = round(indices[0]*100)
    j = round(indices[1]*100)
    k = 100.0-i-j
    
    if i ==0 and j==0 and k==0:
        return 0
    
    return d2[(i,j,k)]
    
generate_heatmap_values([0,0,100])
# Out:
# 0.439453125

# %%
data2 = []

with open('BMG_NiZrAl_predictions_test_1k_3.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    d[0] = float(d[0])
    d[1] = float(d[1])
    d[2] = float(d[2])
    d[3] = float(d[3])
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

# %%
data2 = []

with open('predictions/BMG_NiZrAl_predictions_LB_CoFeZr_rem.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    d[0] = float(d[0])
    d[1] = float(d[1])
    d[2] = float(d[2])
    d[3] = float(d[3])**3
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Ni", fontsize=fontsize)
tax.bottom_axis_label("Al", fontsize=fontsize)

norm = colors.PowerNorm(3.)

# tax.heatmap(d2,style='hexagonal',cmap = "viridis_r")
tax.heatmapf(generate_heatmap_values,style='triangular',
             colorbar=False,
             cmap = "viridis_r",vmin=0, vmax=1
            )
cmap = "viridis_r"
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm._A = []
plt.colorbar(sm,norm=norm)
# tax.boundary()


# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/NiAlZr_LBCoFeZr_rem.png")

# %%
data2 = []

with open('BMG_CoVZr_predictions_5k.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Co
    y = float(d[1]) # V
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    # order: bottom, right, left
    # order: V, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]
# Out:
# 0.306640625

# %%
data2 = []

with open('predictions/BMG_CoVZr_predictions_LB_HiTP_rem.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Co
    y = float(d[1]) # V
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    # order: bottom, right, left
    # order: V, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
fontsize = 15
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Co", fontsize=fontsize)
tax.bottom_axis_label("V", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

# tax.heatmap(d2,style='hexagonal',cmap = "viridis_r")
tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0.5, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/CoVZr_LB_HiTP_rem_scaled.png")

# %%
data2 = []

with open('BMG_FeNbTi_predictions_test.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Fe
    y = float(d[1]) # Nb
    z = float(d[2]) # Ti
    d[3] = float(d[3])
    
    d[0] = z
    d[1] = x
    d[2] = y
    
    # order: bottom, right, left
    # order: Ti, Fe, Nb
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]
# Out:
# 0.5234375

# %%
data2 = []

with open('predictions/BMG_FeNbTi_predictions_LB_HiTP_rem.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Fe
    y = float(d[1]) # Nb
    z = float(d[2]) # Ti
    d[3] = float(d[3])
    
    d[0] = z
    d[1] = x
    d[2] = y
    
    # order: bottom, right, left
    # order: Ti, Fe, Nb
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
mult = 20
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=mult,color="grey")
fontsize = 15

tax.bottom_axis_label("Fe", fontsize=fontsize)
tax.right_axis_label("Nb", fontsize=fontsize)
tax.left_axis_label("Ti", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

# tax.heatmap(d2,style='hexagonal',cmap = "viridis_r")
tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0.5, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=mult)
tax.clear_matplotlib_ticks()

figure.savefig("plots/FeNbTi_LBHiTP_rem_scaled.png")

# %%
data2 = []

with open('predictions/BMG_CoFeZr_predictions_LB_5k.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Co
    y = float(d[1]) # Fe
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = y
    d[1] = x
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
fontsize = 15
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Co", fontsize=fontsize)
tax.bottom_axis_label("Fe", fontsize=fontsize)

# tax.scatter(am,marker='o',color='blue',label = "AM")
# tax.scatter(ac,marker='s',color='green',label="AC")
# tax.scatter(cr,marker='x',color='red',label = "CR")

# tax.heatmap(d2,style='hexagonal',cmap = "viridis_r")
tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0.5, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

# tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/CoFeZr_LB5k_scaled.png")

# %%
data2 = []

with open('predictions/BMG_NiTaZr_predictions_LBHiTP.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Ni
    y = float(d[1]) # Ta
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = x
    d[1] = y
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
fontsize = 15
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Ta", fontsize=fontsize)
tax.bottom_axis_label("Ni", fontsize=fontsize)

tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

# tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/NiTaZr_LBHiTP.png")

# %%
data2 = []

with open('predictions/BMG_BCoCr_predictions_LBHiTP.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # B
    y = float(d[1]) # Co
    z = float(d[2]) # Cr
    d[3] = float(d[3])
    
    d[0] = x
    d[1] = y
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
fontsize = 15
tax.left_axis_label("Cr", fontsize=fontsize)
tax.right_axis_label("Co", fontsize=fontsize)
tax.bottom_axis_label("B", fontsize=fontsize)

tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

# tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/BCoCr_LBHiTP.png")

# %%
data2 = []

with open('predictions/BMG_InMnZn_predictions_LBHiTP.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # In
    y = float(d[1]) # Mn
    z = float(d[2]) # Zn
    d[3] = float(d[3])
    
    d[0] = x
    d[1] = y
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
fontsize = 15
tax.left_axis_label("Zn", fontsize=fontsize)
tax.right_axis_label("Mn", fontsize=fontsize)
tax.bottom_axis_label("In", fontsize=fontsize)

tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

# tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/InMnZn_LBHiTP.png")

# %%
data2 = []

with open('predictions/BMG_CuNiZr_predictions_LBHiTP.csv','r') as f:
    reader = csv.reader(f)
    for row in reader:
        data2.append(row)
        
data2 = data2[1:]

for d in data2:
    x = float(d[0]) # Cu
    y = float(d[1]) # Ni
    z = float(d[2]) # Zr
    d[3] = float(d[3])
    
    d[0] = x
    d[1] = y
    d[2] = z
    
    # order: bottom, right, left
    # order: Fe, Co, Zr
    
data2[1]

d2 = {}
for row in data2:
    d2[(row[0],row[1],row[2])] = row[3]
#     d2[(row[0],row[1])] = row[3]

d2[(0.0,1.0,99.0)]

scale = 100
figure, tax = ternary.figure(scale=scale)
figure.set_size_inches(10,8)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=10,color="grey")
fontsize = 15
tax.left_axis_label("Zr", fontsize=fontsize)
tax.right_axis_label("Ni", fontsize=fontsize)
tax.bottom_axis_label("Cu", fontsize=fontsize)

tax.heatmapf(generate_heatmap_values,style='triangular',
#              colorbar=False,
             cmap = "viridis_r",vmin=0, vmax=1
            )
# cmap = "viridis_r"
# sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# sm._A = []
# plt.colorbar(sm,norm=norm)

# tax.boundary()

# tax.legend()
tax.ticks(axis='lbr', linewidth=1, multiple=10)
tax.clear_matplotlib_ticks()

figure.savefig("plots/CuNiZr_LBHiTP.png")
